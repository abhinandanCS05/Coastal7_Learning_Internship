# %% [markdown]
# **Unzip and Check Uploaded Files**

# %%
# !unzip -q Day_5_FastAPI_SQLAlchemy_Alembic.zip -d /content/
# Out:
# replace /content/alembic.ini? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !ls -lh /content/*.zip
# Out:
# -rw-r--r-- 1 root root 6.1K Sep 22 07:41 /content/Day_5_FastAPI_SQLAlchemy_Alembic.zip

# %%
# !unzip -l /content/Day_5_FastAPI_SQLAlchemy_Alembic.zip
# Out:
# Archive:  /content/Day_5_FastAPI_SQLAlchemy_Alembic.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#       120  2026-09-22 06:36   alembic.ini
#        84  2026-09-22 06:36   requirements.txt
#        80  2026-09-22 06:36   .gitignore
#        80  2026-09-22 06:36   .env.example
#      1329  2026-09-22 06:36   README.md
#      1402  2026-09-22 06:36   alembic/env.py
#       505  2026-09-22 06:36   app/database.py
#       292  2026-09-22 06:36   app/main.py
#         0  2026-09-22 06:36   app/__init__.py
#       429  2026-09-22 06:36   app/models/user.py
#       482  2026-09-22 06:36   app/models/product.py
#        72  2026-09-22 06:36   app/models/__init__.py
#       535  2026-09-22 06:36   app/schemas/user.py
#       484  2026-09-22 06:36   app/schemas/product.py
#         0  2026-09-22 06:36   app/schemas/__init__.py
#      1774  2026-09-22 06:36   app/routers/products.py
#      1770  2026-09-22 06:36   app/routers/users.py
# ...

# %%
# !mkdir -p /content/day5_fastapi
# !unzip -q /content/Day_5_FastAPI_SQLAlchemy_Alembic.zip -d /content/day5_fastapi
# Out:
# replace /content/day5_fastapi/alembic.ini? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !find /content/day5_fastapi -maxdepth 3 -type f | sort
# Out:
# /content/day5_fastapi/alembic/env.py
# /content/day5_fastapi/alembic.ini
# /content/day5_fastapi/alembic/versions/.gitkeep
# /content/day5_fastapi/app/database.py
# /content/day5_fastapi/app/__init__.py
# /content/day5_fastapi/app/main.py
# /content/day5_fastapi/app/models/__init__.py
# /content/day5_fastapi/app/models/product.py
# /content/day5_fastapi/app/models/user.py
# /content/day5_fastapi/app/routers/__init__.py
# /content/day5_fastapi/app/routers/products.py
# /content/day5_fastapi/app/routers/users.py
# /content/day5_fastapi/app/schemas/__init__.py
# /content/day5_fastapi/app/schemas/product.py
# /content/day5_fastapi/app/schemas/user.py
# /content/day5_fastapi/.env.example
# /content/day5_fastapi/.gitignore
# /content/day5_fastapi/README.md
# /content/day5_fastapi/requirements.txt

# %% [markdown]
# # **Install Required Dependencies**

# %%
# %cd /content/day5_fastapi

# !pip install -q -r requirements.txt
# Out:
# /content/day5_fastapi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 41.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 23.4 MB/s eta 0:00:00

# %% [markdown]
# # Install PostgreSQL

# %%
# !apt-get update -qq
# !apt-get install -y postgresql postgresql-contrib -qq
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu noble InRelease' does not seem to provide it (sources.list entry misspelt?)
# Preconfiguring packages ...
# Selecting previously unselected package libjson-perl.
# (Reading database ... 122809 files and directories currently installed.)
# Preparing to unpack .../00-libjson-perl_4.10000-1_all.deb ...
# Unpacking libjson-perl (4.10000-1) ...
# Selecting previously unselected package postgresql-client-common.
# Preparing to unpack .../01-postgresql-client-common_257build1.1_all.deb ...
# Unpacking postgresql-client-common (257build1.1) ...
# Selecting previously unselected package ssl-cert.
# Preparing to unpack .../02-ssl-cert_1.1.2ubuntu1_all.deb ...
# Unpacking ssl-cert (1.1.2ubuntu1) ...
# Selecting previously unselected package postgresql-common.
# Preparing to unpack .../03-postgresql-common_257build1.1_all.deb ...
# ...

# %% [markdown]
# # **Start PostgreSQL**

# %%
# !service postgresql start
# Out:
# [ OK ]

# %% [markdown]
# # **Create the database**

# %%
# !sudo -u postgres psql -c "CREATE DATABASE day5_fastapi;"
# Out:
# CREATE DATABASE

# %% [markdown]
# # **Set the database connection**

# %%
import os

os.environ["DATABASE_URL"] = (
    "postgresql+asyncpg://postgres:postgres@localhost:5432/day5_fastapi"
)

print("✅ DATABASE_URL configured")
# Out:
# ✅ DATABASE_URL configured

# %% [markdown]
# # **Set the PostgreSQL password**

# %%
# !sudo -u postgres psql -c "ALTER USER postgres PASSWORD 'postgres';"
# Out:
# ALTER ROLE

# %% [markdown]
# # **Test SQLAlchemy 2.0 async connection**

# %%
import asyncio
from sqlalchemy import text
from sqlalchemy.ext.asyncio import create_async_engine

DATABASE_URL = os.environ["DATABASE_URL"]

engine = create_async_engine(DATABASE_URL)

async def test_connection():
    async with engine.connect() as connection:
        result = await connection.execute(text("SELECT 1"))
        print("✅ SQLAlchemy async connection successful!")
        print("Result:", result.scalar())

    await engine.dispose()

await test_connection()
# Out:
# ✅ SQLAlchemy async connection successful!
# Result: 1

# %% [markdown]
# # **SQLAlchemy Models**
#
# SQLAlchemy Model — A Python class that represents a PostgreSQL table
#
#
# Check the models

# %%
# %cd /content/day5_fastapi

from app.database import Base
from app.models import User, Product

print("Registered tables:")
print(list(Base.metadata.tables.keys()))
# Out:
# /content/day5_fastapi
# Registered tables:
# ['users', 'products']

# %% [markdown]
# # **Create the Alembic migration**
#
# Alembic migration — A version-controlled set of database changes that creates or modifies database tables.

# %%
# %cd /content/day5_fastapi

from pathlib import Path

env_file = Path("alembic/env.py")
content = env_file.read_text()

content = content.replace(
    "from logging.config import fileConfig",
    "import sys\nfrom pathlib import Path\nsys.path.insert(0, str(Path(__file__).resolve().parents[1]))\n\nfrom logging.config import fileConfig"
)

env_file.write_text(content)

print("✅ Alembic import path fixed")
# Out:
# /content/day5_fastapi
# ✅ Alembic import path fixed

# %% [markdown]
# # Fix alembic.ini

# %%
# %cd /content/day5_fastapi

from pathlib import Path

alembic_ini = Path("alembic.ini")

alembic_ini.write_text("""[alembic]
script_location = alembic
sqlalchemy.url = postgresql+asyncpg://postgres:postgres@localhost:5432/day5_fastapi

[loggers]
keys = root,sqlalchemy,alembic

[handlers]
keys = console

[formatters]
keys = generic

[logger_root]
level = WARN
handlers = console

[logger_sqlalchemy]
level = WARN
handlers =
qualname = sqlalchemy.engine

[logger_alembic]
level = INFO
handlers = console
qualname = alembic

[handler_console]
class = StreamHandler
args = (sys.stderr,)
level = NOTSET
formatter = generic

[formatter_generic]
format = %(levelname)-5.5s [%(name)s] %(message)s
""")

print("✅ alembic.ini logging configuration fixed")
# Out:
# /content/day5_fastapi
# ✅ alembic.ini logging configuration fixed

# %% [markdown]
# # **Create the  Alembic template**

# %%
# %cd /content/day5_fastapi

from pathlib import Path

template = '''"""${message}

Revision ID: ${up_revision}
Revises: ${down_revision | comma,n}
Create Date: ${create_date}
"""

from typing import Sequence, Union

from alembic import op
import sqlalchemy as sa
${imports if imports else ""}

# revision identifiers, used by Alembic.
revision: str = ${repr(up_revision)}
down_revision: Union[str, Sequence[str], None] = ${repr(down_revision)}
branch_labels: Union[str, Sequence[str], None] = ${repr(branch_labels)}
depends_on: Union[str, Sequence[str], None] = ${repr(depends_on)}


def upgrade() -> None:
    ${upgrades if upgrades else "pass"}


def downgrade() -> None:
    ${downgrades if downgrades else "pass"}
'''

Path("alembic/script.py.mako").write_text(template)

print("✅ Alembic script template created")
# Out:
# /content/day5_fastapi
# ✅ Alembic script template created

# %% [markdown]
# # **Generate the migration**

# %%
# !alembic revision --autogenerate -m "create users and products"
# Out:
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.schemas
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.schemas
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.tables
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.tables
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.types
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.types
# INFO  [alembic.runtime.plugins] setting up autogenerate plugin alembic.autogenerate.constraints
# ...

# %% [markdown]
# # **Apply the migration**
#
# alembic upgrade head — Applies the latest migration to the PostgreSQL database.

# %%
# !alembic upgrade head
# Out:
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Will assume transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> 6e7371b897d5, create users and products
# INFO  [alembic.runtime.migration] Running upgrade  -> 6e7371b897d5, create users and products

# %% [markdown]
# # **Verify the PostgreSQL tables**
#
# Let's confirm the migration actually created the tables.

# %%
# !sudo -u postgres psql -P pager=off -d day5_fastapi -c "\dt"
# Out:
#               List of relations
#  Schema |      Name       | Type  |  Owner
# --------+-----------------+-------+----------
#  public | alembic_version | table | postgres
#  public | products        | table | postgres
#  public | users           | table | postgres
# (3 rows)

# %% [markdown]
# # **Practice Pydantic V2 validation**
#
# Pydantic Schema — A typed model that validates the data entering or leaving an API.
#
#
# Our UserCreate schema uses:
#
# Field() → basic constraints
# field_validator() → custom field validation
# EmailStr → email validation

# %%
from app.schemas.user import UserCreate

# Valid data
user = UserCreate(
    name="  Abhi  ",
    email="abhi@example.com"
)

print("Name:", user.name)
print("Email:", user.email)
# Out:
# Name: Abhi
# Email: abhi@example.com

# %% [markdown]
# # **Test invalid Pydantic data**
#
# Validation — Pydantic automatically rejects data that does not satisfy the schema rules.
#
# Let's test two common errors: a name that's too short and an invalid email.

# %%
from app.schemas.user import UserCreate

try:
    UserCreate(
        name="A",
        email="wrong-email"
    )
except Exception as e:
    print("❌ Validation failed as expected:")
    print(e)
# Out:
# ❌ Validation failed as expected:
# 2 validation errors for UserCreate
# name
#   String should have at least 2 characters [type=string_too_short, input_value='A', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/string_too_short
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='wrong-email', input_type=str]

# %% [markdown]
# # **Create a User through the SQLAlchemy async layer**
#
# Before starting the FastAPI server, let's verify that our Pydantic → SQLAlchemy → PostgreSQL flow works.
#
# **CRUD Create** — Convert validated Pydantic data into a SQLAlchemy model and save it to PostgreSQL.

# %%
from app.database import AsyncSessionLocal
from app.models.user import User
from app.schemas.user import UserCreate

async def create_test_user():
    data = UserCreate(
        name="Abhi",
        email="abhi_day5@example.com"
    )

    async with AsyncSessionLocal() as db:
        user = User(
            name=data.name,
            email=data.email
        )

        db.add(user)
        await db.commit()
        await db.refresh(user)

        print("✅ User created successfully!")
        print("ID:", user.id)
        print("Name:", user.name)
        print("Email:", user.email)

await create_test_user()
# Out:
# ✅ User created successfully!
# ID: 1
# Name: Abhi
# Email: abhi_day5@example.com

# %% [markdown]
# # **Start the FastAPI server**
#
# FastAPI Integration — Connect the existing FastAPI routes to the SQLAlchemy database layer.

# %%
# %cd /content/day5_fastapi

# !nohup uvicorn app.main:app --host 0.0.0.0 --port 8000 > /tmp/day5_fastapi.log 2>&1 &
# Out:
# /content/day5_fastapi

# %%
# !sleep 2
# !cat /tmp/day5_fastapi.log
# Out:
# INFO:     Started server process [38019]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)

# %% [markdown]
# # **Test User CRUD API**
#
# We'll use requests from Colab, so there is no need to repeat Swagger setup from Day 1.
#
#  **Create User**

# %%
import requests

BASE_URL = "http://127.0.0.1:8000"

response = requests.post(
    f"{BASE_URL}/users/",
    json={
        "name": "Rahul",
        "email": "rahul_day5@example.com"
    }
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'id': 2, 'name': 'Rahul', 'email': 'rahul_day5@example.com'}

# %% [markdown]
# **Read Users**

# %%
response = requests.get(f"{BASE_URL}/users/")

print("Status:", response.status_code)
print("Users:", response.json())
# Out:
# Status: 200
# Users: [{'id': 1, 'name': 'Abhi', 'email': 'abhi_day5@example.com'}, {'id': 2, 'name': 'Rahul', 'email': 'rahul_day5@example.com'}]

# %% [markdown]
# **Update Users**

# %%
user_id = response.json()[0]["id"]

response = requests.put(
    f"{BASE_URL}/users/{user_id}",
    json={"name": "Rahul Updated"}
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'id': 1, 'name': 'Rahul Updated', 'email': 'abhi_day5@example.com'}

# %% [markdown]
# **Delete User**

# %%
response = requests.delete(f"{BASE_URL}/users/{user_id}")

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 200
# Response: {'message': 'User deleted successfully'}

# %% [markdown]
# POST   → Create
# GET    → Read
# PUT    → Update
# DELETE → Delete

# %% [markdown]
# # **Products CRUD**
#
# **Product CRUD** — Create, read, update, and delete product records through the FastAPI API.
#
# Because Product has an owner_id, this also demonstrates the User → Product relationship.
#
# **Create a Product**
#
# Use an existing user ID. Since we created a test user earlier, use 1 if that user still exists:

# %%
product_response = requests.post(
    f"{BASE_URL}/products/",
    json={
        "name": "Laptop",
        "price": 75000,
        "owner_id": 1
    }
)

print("Status:", product_response.status_code)

if product_response.status_code == 200:
    print("Response:", product_response.json())
else:
    print("Error Response Text:", product_response.text)
# Out:
# Status: 500
# Error Response Text: Internal Server Error

# %% [markdown]
# **Read Products**

# %%
response = requests.get(f"{BASE_URL}/products/")

print("Status:", response.status_code)
print("Products:", response.json())
# Out:
# Status: 200
# Products: []

# %% [markdown]
# **Update Products**

# %%
products = response.json()

if products:
    product_id = products[0]["id"]

    response = requests.put(
        f"{BASE_URL}/products/{product_id}",
        json={
            "price": 70000
        }
    )

    print("Status:", response.status_code)
    print("Response:", response.json())
else:
    print("No products found to update.")
# Out:
# No products found to update.

# %% [markdown]
# **Delete Product**

# %%
products_to_delete = requests.get(f"{BASE_URL}/products/").json()

if products_to_delete:
    product_id_to_delete = products_to_delete[0]["id"]

    response = requests.delete(
        f"{BASE_URL}/products/{product_id_to_delete}"
    )

    print("Status:", response.status_code)
    if response.status_code == 200:
        print("Response:", response.json())
    else:
        print("Error Response Text:", response.text)
else:
    print("No products found to delete.")
# Out:
# No products found to delete.

# %% [markdown]
# # **Test Product Validation**
#
# This verifies that the Pydantic V2 validation layer also protects the Product API.
#
# **Validation** — Reject invalid request data before it reaches the database.

# %%
response = requests.post(
    f"{BASE_URL}/products/",
    json={
        "name": "A",
        "price": -100,
        "owner_id": 0
    }
)

print("Status:", response.status_code)
print("Response:", response.json())
# Out:
# Status: 422
# Response: {'detail': [{'type': 'string_too_short', 'loc': ['body', 'name'], 'msg': 'String should have at least 2 characters', 'input': 'A', 'ctx': {'min_length': 2}}, {'type': 'greater_than', 'loc': ['body', 'price'], 'msg': 'Input should be greater than 0', 'input': -100, 'ctx': {'gt': 0.0}}, {'type': 'greater_than', 'loc': ['body', 'owner_id'], 'msg': 'Input should be greater than 0', 'input': 0, 'ctx': {'gt': 0}}]}

# %% [markdown]
# **Verify the complete Day 5 stack**
#
# Final Integration — Confirm that FastAPI, Pydantic V2, SQLAlchemy 2.0, PostgreSQL, and Alembic work together.

# %%
import requests
import subprocess

BASE_URL = "http://127.0.0.1:8000"

# 1. FastAPI
root = requests.get(f"{BASE_URL}/")
print("FastAPI:", root.status_code, "✅")

# 2. Users API
users = requests.get(f"{BASE_URL}/users/")
print("Users API:", users.status_code, "✅")

# 3. Products API
products = requests.get(f"{BASE_URL}/products/")
print("Products API:", products.status_code, "✅")

# 4. Alembic migration status
result = subprocess.run(
    ["alembic", "current"],
    capture_output=True,
    text=True
)

print("\nAlembic:")
print(result.stdout)
# Out:
# FastAPI: 200 ✅
# Users API: 200 ✅
# Products API: 200 ✅
#
# Alembic:
# 6e7371b897d5 (head)

# %% [markdown]
# # **Git Workflow**

# %%
# %cd /content/day5_fastapi

# !git init
# !git config user.name "abhinandanCS05"
# !git config user.email "abhinandanC5-G7@coastalseven.com"

# Connect to your existing GitHub repository
# !git remote remove origin 2>/dev/null || true
# !git remote add origin https://github.com/abhinandanCS05/Coastal7_Learning_Internship.git

# Create the new Day 5 branch
# !git checkout -b day5-fastapi

# Add the entire Day 5 project
# !git add .

# Commit
# !git commit -m "Day 5 FastAPI SQLAlchemy Alembic"

# Verify
# !git branch --show-current
# !git status
# Out:
# /content/day5_fastapi
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/day5_fastapi/.git/
# Switched to a new branch 'day5-fastapi'
# [day5-fastapi (root-commit) 7f4430c] Day 5 FastAPI SQLAlchemy Alembic
#  20 files changed, 330 insertions(+)
#  create mode 100644 .env.example
#  create mode 100644 .gitignore
#  create mode 100644 README.md
#  create mode 100644 alembic.ini
#  create mode 100644 alembic/env.py
#  create mode 100644 alembic/script.py.mako
# ...

# %%
from getpass import getpass
import subprocess
import os

token = getpass("Enter your NEW GitHub token: ")

os.environ["GIT_USERNAME"] = "abhinandanCS05"
os.environ["GIT_TOKEN"] = token
os.environ["GIT_ASKPASS"] = "/tmp/git-askpass.sh"

with open("/tmp/git-askpass.sh", "w") as f:
    f.write("""#!/bin/sh
case "$1" in
  *Username*) printf '%s' "$GIT_USERNAME" ;;
  *Password*) printf '%s' "$GIT_TOKEN" ;;
esac
""")

os.chmod("/tmp/git-askpass.sh", 0o700)

result = subprocess.run(
    ["git", "push", "-u", "origin", "day5-fastapi"],
    capture_output=True,
    text=True
)

print(result.stdout)
print(result.stderr)

# Clean up credentials
os.environ.pop("GIT_TOKEN", None)
os.environ.pop("GIT_USERNAME", None)
os.environ.pop("GIT_ASKPASS", None)
os.remove("/tmp/git-askpass.sh")
# Out:
# Enter your NEW GitHub token: ··········
# branch 'day5-fastapi' set up to track 'origin/day5-fastapi'.
#
# remote:
# remote: Create a pull request for 'day5-fastapi' on GitHub by visiting:
# remote:      https://github.com/abhinandanCS05/Coastal7_Learning_Internship/pull/new/day5-fastapi
# remote:
# To https://github.com/abhinandanCS05/Coastal7_Learning_Internship.git
#  * [new branch]      day5-fastapi -> day5-fastapi

# %%
# %cd /content/day5_fastapi

# Remove the rule that ignores Alembic migration files
# !sed -i '/alembic\/versions\/\*\.py/d' .gitignore

# Check the migration exists
# !ls -lh alembic/versions/

# Add the migration and updated gitignore
# !git add .gitignore alembic/versions/6e7371b897d5_create_users_and_products.py

# Commit
# !git commit -m "Add Alembic migration"

# Push the additional commit
# !git push
# Out:
# /content/day5_fastapi
# total 8.0K
# -rw-r--r-- 1 root root 1.5K Sep 22 09:45 6e7371b897d5_create_users_and_products.py
# drwxr-xr-x 2 root root 4.0K Sep 22 09:45 __pycache__
# [day5-fastapi 04e693a] Add Alembic migration
#  2 files changed, 46 insertions(+), 1 deletion(-)
#  create mode 100644 alembic/versions/6e7371b897d5_create_users_and_products.py
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git status
# !git log --oneline -2
# Out:
# On branch day5-fastapi
# Your branch is ahead of 'origin/day5-fastapi' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# 04e693a (HEAD -> day5-fastapi) Add Alembic migration
# 7f4430c (origin/day5-fastapi) Day 5 FastAPI SQLAlchemy Alembic
